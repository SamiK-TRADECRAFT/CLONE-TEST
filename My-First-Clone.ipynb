# %% [markdown]
# <h4>If you can see the following content with cells 1 and 2 and the OSINT image below, then you have successfully cloned and accessed this gitHub repo on Jupyter Notebook. Congratulations!</h4>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
5 + 9
# Out:
# 14

# %% [markdown]
# #### OSINT: Conversations in Social Media

# %% [markdown]
# <img src="https://miro.medium.com/max/2636/1*Dpf3zGMTvMZ94ydA2qIYmA.png">
